# %%
a=int(input("Enter number: "))
if a%5==0:
  print(" Number is divisible by 5")
elif a%11== 0:
    print("Number is divisilble by 11")
else:
    print("THIS Number cant be divided by 5 or 11")
# Out:
# Enter number: 2
# THIS Number cant be divided by 5 or 11
