# %%
print("Enter the number you want to find prime")
a=int(input())
flag = 0
if a > 1:
    for i in range(2, a):
        if (a % i) == 0:
            flag = 1
            break
if flag:
    print(a, "is not a prime number")
else:
    print(a, "is a prime number")
# Out:
# Enter the number you want to find prime
# 20
# 20 is not a prime number
